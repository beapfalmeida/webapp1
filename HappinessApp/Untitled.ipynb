# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("happy.csv")
df
# Out:
#                   country  happiness   gdp  social_support  life_expectancy  \
# 0                   Niger       5003   570             560              326
# 1              Mozambique       5048   578             660              191
# 2                 Liberia       5122   636             670              309
# 3                  Malawi       3750   648             279              388
# 4                    Chad       4251   662             506              225
# ..                    ...        ...   ...             ...              ...
# 140  United Arab Emirates       6576  1998             980              633
# 141           Switzerland       7512  2026            1226              822
# 142               Ireland       7041  2129            1166              779
# 143             Singapore       6480  2149            1127              851
# 144            Luxembourg       7404  2209            1155              790
#
# ...

# %%
df.columns
# Out:
# Index(['country', 'happiness', 'gdp', 'social_support', 'life_expectancy',
#        'freedom_to_make_life_choices', 'generosity', 'corruption'],
#       dtype='object')

# %%
df.plot(x='happiness', y='gdp', figsize=(15,3))
# Out:
# <Axes: xlabel='happiness'>

# %%
list(df['happiness'])
# Out:
# [5003,
#  5048,
#  5122,
#  3750,
#  4251,
#  4339,
#  3574,
#  4197,
#  2404,
#  4112,
#  4603,
#  4670,
#  5164,
#  3268,
#  4241,
#  4479,
#  3512,
#  4891,
#  3702,
#  4609,
#  3760,
#  4623,
#  5046,
#  2995,
#  5075,
#  5377,
#  5048,
#  5377,
#  4640,
#  4543,
#  4394,
#  4516,
#  5155,
#  5828,
#  4552,
#  5235,
#  4153,
#  6165,
#  6022,
#  4872,
#  4483,
#  3777,
#  5060,
#  6063,
#  5140,
#  5485,
#  5600,
#  6120,
#  5904,
#  6262,
#  4396,
#  4941,
#  4459,
#  5850,
#  4152,
#  4516,
#  5533,
#  6455,
#  5122,
#  5240,
#  4288,
#  2955,
#  5761,
#  5559,
#  5578,
#  4888,
#  5084,
#  4362,
#  5857,
#  5194,
#  5399,
#  5199,
#  5781,
#  5173,
#  4958,
#  6293,
#  4973,
#  5768,
#  5330,
#  5474,
#  3471,
#  5199,
#  5585,
#  5891,
#  5737,
#  6178,
#  6128,
#  5821,
#  5547,
#  6582,
#  6071,
#  5967,
#  6474,
#  5371,
#  6172,
#  6234,
#  5459,
#  5711,
#  5948,
#  6125,
#  4744,
#  6309,
#  6477,
#  6180,
#  6391,
#  6086,
#  6123,
#  6016,
#  6341,
#  6446,
#  6476,
# ...
